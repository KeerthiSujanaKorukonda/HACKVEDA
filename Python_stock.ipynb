# %%
pip install alpha_vantage
# Out:
# Collecting alpha_vantage
#   Downloading alpha_vantage-2.3.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from alpha_vantage) (3.9.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from alpha_vantage) (2.31.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (2024.6.2)
# Installing collected packages: alpha_vantage
# Successfully installed alpha_vantage-2.3.1

# %%
from alpha_vantage.timeseries import TimeSeries
API_KEY = '8FHEYWXTU6IPYSH4'
ts= TimeSeries(key = API_KEY, output_format= 'pandas' )
data = ts.get_monthly_adjusted('MSFT')
data[0]
# Out:
#             1. open  2. high    3. low  4. close  5. adjusted close  \
# date
# 2024-06-13  415.525   443.40  408.9234    441.58           441.5800
# 2024-05-31  392.610   433.60  390.3100    415.13           415.1300
# 2024-04-30  423.950   429.37  388.0300    389.33           388.6411
# 2024-03-28  411.270   430.82  398.3900    420.72           419.9755
# 2024-02-29  401.830   420.82  397.2200    413.64           412.9080
# ...             ...      ...       ...       ...                ...
# 2000-04-28   94.440    96.50   65.0000     69.75            21.5879
# 2000-03-31   89.620   115.00   88.9400    106.25            32.8848
# 2000-02-29   98.500   110.00   88.1200     89.37            27.6603
# 2000-01-31  117.370   118.62   94.8700     97.87            30.2911
# 1999-12-31   91.060   119.94   90.8700    116.75            36.1346
#
#                6. volume  7. dividend amount
# date
# 2024-06-13  1.441855e+08                0.00
# 2024-05-31  4.138104e+08                0.75
# 2024-04-30  4.401195e+08                0.00
# 2024-03-28  4.251017e+08                0.00
# 2024-02-29  4.442035e+08                0.75
# ...                  ...                 ...
# 2000-04-28  1.129073e+09                0.00
# 2000-03-31  1.014094e+09                0.00
# 2000-02-29  6.672438e+08                0.00
# 2000-01-31  6.374376e+08                0.00
# 1999-12-31  6.304889e+08                0.00
#
# [295 rows x 7 columns]

# %%
from alpha_vantage.timeseries import TimeSeries
API_KEY = '8FHEYWXTU6IPYSH4'
ts= TimeSeries(key = API_KEY, output_format= 'pandas' )
data = ts.get_monthly_adjusted('AAPL')
data[0]
# Out:
#             1. open  2. high   3. low  4. close  5. adjusted close  \
# date
# 2024-06-13  192.900   220.20  192.150    214.24           214.2400
# 2024-05-31  169.580   193.00  169.110    192.25           192.2500
# 2024-04-30  171.190   178.36  164.075    170.33           170.0977
# 2024-03-28  179.550   180.53  168.490    171.48           171.2461
# 2024-02-29  183.985   191.05  179.250    180.75           180.5035
# ...             ...      ...      ...       ...                ...
# 2000-04-28  135.500   139.50  104.870    124.06             0.9364
# 2000-03-31  118.560   150.38  114.000    135.81             1.0251
# 2000-02-29  104.000   119.94   97.000    114.62             0.8651
# 2000-01-31  104.870   121.50   86.500    103.75             0.7831
# 1999-12-31  101.000   118.00   91.060    102.81             0.7760
#
#                6. volume  7. dividend amount
# date
# 2024-06-13  8.116268e+08                0.00
# 2024-05-31  1.336570e+09                0.25
# 2024-04-30  1.240411e+09                0.00
# 2024-03-28  1.430780e+09                0.00
# 2024-02-29  1.161712e+09                0.24
# ...                  ...                 ...
# 2000-04-28  7.734290e+07                0.00
# 2000-03-31  7.766390e+07                0.00
# 2000-02-29  6.535520e+07                0.00
# 2000-01-31  1.120998e+08                0.00
# 1999-12-31  8.409120e+07                0.00
#
# [295 rows x 7 columns]

# %%
from alpha_vantage.timeseries import TimeSeries
API_KEY = '8FHEYWXTU6IPYSH4'
ts= TimeSeries(key = API_KEY, output_format= 'pandas' )
data = ts.get_intraday('AAPL',interval = '15min')
data[0]
# Out:
#                      1. open  2. high   3. low  4. close  5. volume
# date
# 2024-06-13 19:45:00  214.300  214.600  214.140   214.420    26275.0
# 2024-06-13 19:30:00  214.260  214.340  214.240   214.300    15650.0
# 2024-06-13 19:15:00  214.180  214.340  214.030   214.260    12949.0
# 2024-06-13 19:00:00  214.398  214.400  214.100   214.180    13999.0
# 2024-06-13 18:45:00  214.380  214.490  214.380   214.400    16081.0
# ...                      ...      ...      ...       ...        ...
# 2024-06-12 12:00:00  216.510  217.490  216.183   216.815  3782135.0
# 2024-06-12 11:45:00  216.450  216.895  216.180   216.507  4260743.0
# 2024-06-12 11:30:00  217.580  217.610  216.360   216.470  4734165.0
# 2024-06-12 11:15:00  217.310  218.040  217.211   217.580  5750240.0
# 2024-06-12 11:00:00  216.610  218.120  216.500   217.320  8921979.0
#
# [100 rows x 5 columns]

# %%
from alpha_vantage.timeseries import TimeSeries
API_KEY = '8FHEYWXTU6IPYSH4'
ts= TimeSeries(key = API_KEY, output_format= 'pandas' )
data = ts.get_intraday('AAPL',interval = '5min')
data[0]
# Out:
#                      1. open  2. high   3. low  4. close  5. volume
# date
# 2024-06-13 19:55:00  214.315  214.600  214.140   214.420    10082.0
# 2024-06-13 19:50:00  214.330  214.370  214.300   214.330     8154.0
# 2024-06-13 19:45:00  214.300  214.370  214.300   214.350     8039.0
# 2024-06-13 19:40:00  214.300  214.325  214.240   214.300     7297.0
# 2024-06-13 19:35:00  214.280  214.300  214.240   214.270     5458.0
# ...                      ...      ...      ...       ...        ...
# 2024-06-13 12:00:00  213.745  213.745  212.871   213.067   898384.0
# 2024-06-13 11:55:00  213.860  213.880  213.690   213.740   531034.0
# 2024-06-13 11:50:00  213.888  213.910  213.580   213.862   487523.0
# 2024-06-13 11:45:00  213.927  214.062  213.780   213.880   641460.0
# 2024-06-13 11:40:00  213.450  213.970  213.432   213.935   530035.0
#
# [100 rows x 5 columns]

# %%
from alpha_vantage.fundamentaldata import FundamentalData
key = '3UNSXNXNOKMFUZ6I'
fd = FundamentalData(key, output_format= 'pandas' )
data= fd.get_income_statement_annual('MSFT')
data[0].T
# Out:
# date                              1970-01-01 00:00:00.000000000  \
# fiscalDateEnding                                     2023-06-30
# reportedCurrency                                            USD
# grossProfit                                        146052000000
# totalRevenue                                       209747000000
# costOfRevenue                                      100049000000
# costofGoodsAndServicesSold                          65863000000
# operatingIncome                                     88523000000
# sellingGeneralAndAdministrative                     30334000000
# researchAndDevelopment                              27195000000
# operatingExpenses                                   61381000000
# investmentIncomeNet                                  2994000000
# netInterestIncome                                   -1968000000
# interestIncome                                       1041000000
# interestExpense                                      1968000000
# nonInterestIncome                                  211715000000
# otherNonOperatingIncome                              -223000000
# depreciation                                        11000000000
# depreciationAndAmortization                          3852000000
# incomeBeforeTax                                     89311000000
# incomeTaxExpense                                    16950000000
# interestAndDebtExpense                               1968000000
# netIncomeFromContinuingOperations                   72361000000
# comprehensiveIncomeNetOfTax                         70696000000
# ebit                                                91279000000
# ebitda                                              95131000000
# netIncome                                           72361000000
#
# date                              1970-01-01 00:00:00.000000001  \
# fiscalDateEnding                                     2022-06-30
# reportedCurrency                                            USD
# grossProfit                                        135620000000
# totalRevenue                                       196109000000
# costOfRevenue                                       93355000000
# costofGoodsAndServicesSold                          62650000000
# operatingIncome                                     83383000000
# sellingGeneralAndAdministrative                     27725000000
# researchAndDevelopment                              24512000000
# operatingExpenses                                   55217000000
# investmentIncomeNet                                  2094000000
# netInterestIncome                                   -2063000000
# interestIncome                                       2094000000
# interestExpense                                      2063000000
# nonInterestIncome                                  198172000000
# otherNonOperatingIncome                               -32000000
# depreciation                                        12600000000
# depreciationAndAmortization                          2980000000
# incomeBeforeTax                                     83716000000
# incomeTaxExpense                                    10978000000
# interestAndDebtExpense                               2063000000
# netIncomeFromContinuingOperations                   72738000000
# comprehensiveIncomeNetOfTax                         66238000000
# ebit                                                85779000000
# ebitda                                              88759000000
# netIncome                                           72738000000
#
# date                              1970-01-01 00:00:00.000000002  \
# fiscalDateEnding                                     2021-06-30
# reportedCurrency                                            USD
# grossProfit                                        115856000000
# totalRevenue                                       165936000000
# costOfRevenue                                       79977000000
# costofGoodsAndServicesSold                          52232000000
# operatingIncome                                     69916000000
# sellingGeneralAndAdministrative                     25224000000
# researchAndDevelopment                              20716000000
# operatingExpenses                                   48461000000
# investmentIncomeNet                                  2131000000
# netInterestIncome                                   -2346000000
# interestIncome                                       2131000000
# interestExpense                                      2346000000
# nonInterestIncome                                  168282000000
# otherNonOperatingIncome                                98000000
# depreciation                                         9300000000
# depreciationAndAmortization                          2521000000
# incomeBeforeTax                                     71102000000
# incomeTaxExpense                                     9831000000
# interestAndDebtExpense                               2346000000
# netIncomeFromContinuingOperations                   61271000000
# comprehensiveIncomeNetOfTax                         59897000000
# ebit                                                73448000000
# ebitda                                              75969000000
# netIncome                                           61271000000
#
# date                              1970-01-01 00:00:00.000000003  \
# fiscalDateEnding                                     2020-06-30
# reportedCurrency                                            USD
# grossProfit                                         96937000000
# totalRevenue                                       140503000000
# costOfRevenue                                       73159000000
# costofGoodsAndServicesSold                          46078000000
# operatingIncome                                     52959000000
# sellingGeneralAndAdministrative                     24709000000
# researchAndDevelopment                              19269000000
# operatingExpenses                                   46350000000
# investmentIncomeNet                                  2680000000
# netInterestIncome                                   -2591000000
# interestIncome                                       2680000000
# interestExpense                                      2591000000
# nonInterestIncome                                  143094000000
# otherNonOperatingIncome                               -40000000
# depreciation                                        10700000000
# depreciationAndAmortization                          2211000000
# incomeBeforeTax                                     53036000000
# incomeTaxExpense                                     8755000000
# interestAndDebtExpense                               2591000000
# netIncomeFromContinuingOperations                   44281000000
# comprehensiveIncomeNetOfTax                         47807000000
# ebit                                                55627000000
# ebitda                                              57838000000
# netIncome                                           44281000000
#
# date                              1970-01-01 00:00:00.000000004  \
# fiscalDateEnding                                     2019-06-30
# reportedCurrency                                            USD
# grossProfit                                         82933000000
# totalRevenue                                       123495000000
# costOfRevenue                                       67908000000
# costofGoodsAndServicesSold                          42910000000
# operatingIncome                                     42959000000
# sellingGeneralAndAdministrative                     23098000000
# researchAndDevelopment                              16876000000
# operatingExpenses                                   41874000000
# investmentIncomeNet                                  2762000000
# netInterestIncome                                   -2686000000
# interestIncome                                        812000000
# interestExpense                                      2686000000
# nonInterestIncome                                  126181000000
# otherNonOperatingIncome                               -57000000
# depreciation                                         9700000000
# depreciationAndAmortization                          1900000000
# incomeBeforeTax                                     43688000000
# incomeTaxExpense                                     4448000000
# interestAndDebtExpense                               2686000000
# netIncomeFromContinuingOperations                   39240000000
# comprehensiveIncomeNetOfTax                         41154000000
# ebit                                                46374000000
# ebitda                                              48274000000
# netIncome                                           39240000000
#
# date                              1970-01-01 00:00:00.000000005  \
# fiscalDateEnding                                     2018-06-30
# reportedCurrency                                            USD
# grossProfit                                         72007000000
# totalRevenue                                       107222000000
# costOfRevenue                                       62776000000
# costofGoodsAndServicesSold                          38353000000
# operatingIncome                                     35058000000
# sellingGeneralAndAdministrative                     22223000000
# researchAndDevelopment                              14726000000
# operatingExpenses                                   39149000000
# investmentIncomeNet                                  2214000000
# netInterestIncome                                   -2733000000
# interestIncome                                       1522000000
# interestExpense                                      2733000000
# nonInterestIncome                                  109955000000
# otherNonOperatingIncome                               -59000000
# depreciation                                         7700000000
# depreciationAndAmortization                          2200000000
# incomeBeforeTax                                     36474000000
# incomeTaxExpense                                    19903000000
# interestAndDebtExpense                               2733000000
# netIncomeFromContinuingOperations                   16571000000
# comprehensiveIncomeNetOfTax                         13715000000
# ebit                                                39207000000
# ebitda                                              41407000000
# netIncome                                           16571000000
#
# date                              1970-01-01 00:00:00.000000006  \
# fiscalDateEnding                                     2017-06-30
# reportedCurrency                                            USD
# grossProfit                                         62310000000
# totalRevenue                                        96571000000
# costOfRevenue                                       34261000000
# costofGoodsAndServicesSold                          34261000000
# operatingIncome                                     29025000000
# sellingGeneralAndAdministrative                     20020000000
# researchAndDevelopment                              13037000000
# operatingExpenses                                   35063000000
# investmentIncomeNet                                  1387000000
# netInterestIncome                                   -2222000000
# interestIncome                                       1182000000
# interestExpense                                      2222000000
# nonInterestIncome                                    -674000000
# otherNonOperatingIncome                              -251000000
# depreciation                                         6100000000
# depreciationAndAmortization                          1700000000
# incomeBeforeTax                                     29901000000
# incomeTaxExpense                                     4412000000
# interestAndDebtExpense                               2222000000
# netIncomeFromContinuingOperations                   21204000000
# comprehensiveIncomeNetOfTax                         24322000000
# ebit                                                32123000000
# ebitda                                              33823000000
# netIncome                                           25489000000
#
# date                              1970-01-01 00:00:00.000000007  \
# fiscalDateEnding                                     2016-06-30
# reportedCurrency                                            USD
# grossProfit                                         58374000000
# totalRevenue                                        91154000000
# costOfRevenue                                       32780000000
# costofGoodsAndServicesSold                          32780000000
# operatingIncome                                     26078000000
# sellingGeneralAndAdministrative                     19260000000
# researchAndDevelopment                              11988000000
# operatingExpenses                                   33357000000
# investmentIncomeNet                                   903000000
# netInterestIncome                                   -1243000000
# interestIncome                                         78000000
# interestExpense                                      1243000000
# nonInterestIncome                                    -564000000
# otherNonOperatingIncome                              -195000000
# depreciation                                         4900000000
# depreciationAndAmortization                           978000000
# incomeBeforeTax                                     25639000000
# incomeTaxExpense                                     5100000000
# interestAndDebtExpense                               1243000000
# netIncomeFromContinuingOperations                   16798000000
# comprehensiveIncomeNetOfTax                         19811000000
# ebit                                                26882000000
# ebitda                                              27860000000
# netIncome                                           20539000000
#
# date                              1970-01-01 00:00:00.000000008  \
# fiscalDateEnding                                     2015-06-30
# reportedCurrency                                            USD
# grossProfit                                         60542000000
# totalRevenue                                        93580000000
# costOfRevenue                                       33038000000
# costofGoodsAndServicesSold                          21410000000
# operatingIncome                                     18161000000
# sellingGeneralAndAdministrative                     20324000000
# researchAndDevelopment                              12046000000
# operatingExpenses                                   42381000000
# investmentIncomeNet                                   766000000
# netInterestIncome                                    -781000000
# interestIncome                                             None
# interestExpense                                       781000000
# nonInterestIncome                                     -88000000
# otherNonOperatingIncome                              -267000000
# depreciation                                         4100000000
# depreciationAndAmortization                          1300000000
# incomeBeforeTax                                     18507000000
# incomeTaxExpense                                     6314000000
# interestAndDebtExpense                                781000000
# netIncomeFromContinuingOperations                   12193000000
# comprehensiveIncomeNetOfTax                         11007000000
# ebit                                                19288000000
# ebitda                                              20588000000
# netIncome                                           12193000000
#
# date                              1970-01-01 00:00:00.000000009  \
# fiscalDateEnding                                     2014-06-30
# reportedCurrency                                            USD
# grossProfit                                         59755000000
# totalRevenue                                        86833000000
# costOfRevenue                                       27078000000
# costofGoodsAndServicesSold                          16681000000
# operatingIncome                                     27759000000
# sellingGeneralAndAdministrative                     20632000000
# researchAndDevelopment                              11381000000
# operatingExpenses                                   31996000000
# investmentIncomeNet                                   883000000
# netInterestIncome                                    -597000000
# interestIncome                                             None
# interestExpense                                       597000000
# nonInterestIncome                                    -199000000
# otherNonOperatingIncome                              -169000000
# depreciation                                         3400000000
# depreciationAndAmortization                           845000000
# incomeBeforeTax                                     27820000000
# incomeTaxExpense                                     5746000000
# interestAndDebtExpense                                597000000
# netIncomeFromContinuingOperations                   22074000000
# comprehensiveIncomeNetOfTax                         24039000000
# ebit                                                28417000000
# ebitda                                              29262000000
# netIncome                                           22074000000
#
# date                              1970-01-01 00:00:00.000000010  \
# fiscalDateEnding                                     2013-06-30
# reportedCurrency                                            USD
# grossProfit                                         57464000000
# totalRevenue                                        77849000000
# costOfRevenue                                       20385000000
# costofGoodsAndServicesSold                          20385000000
# operatingIncome                                     26764000000
# sellingGeneralAndAdministrative                     20425000000
# researchAndDevelopment                              10411000000
# operatingExpenses                                   30700000000
# investmentIncomeNet                                   677000000
# netInterestIncome                                    -429000000
# interestIncome                                             None
# interestExpense                                       429000000
# nonInterestIncome                                    -270000000
# otherNonOperatingIncome                               194000000
# depreciation                                         2600000000
# depreciationAndAmortization                           739000000
# incomeBeforeTax                                     27052000000
# incomeTaxExpense                                     5189000000
# interestAndDebtExpense                                429000000
# netIncomeFromContinuingOperations                   21863000000
# comprehensiveIncomeNetOfTax                         22184000000
# ebit                                                27481000000
# ebitda                                              28220000000
# netIncome                                           21863000000
#
# date                              1970-01-01 00:00:00.000000011  \
# fiscalDateEnding                                     2012-06-30
# reportedCurrency                                            USD
# grossProfit                                         56193000000
# totalRevenue                                        73723000000
# costOfRevenue                                       17530000000
# costofGoodsAndServicesSold                          17530000000
# operatingIncome                                     21763000000
# sellingGeneralAndAdministrative                     18426000000
# researchAndDevelopment                               9811000000
# operatingExpenses                                   34430000000
# investmentIncomeNet                                   800000000
# netInterestIncome                                    -380000000
# interestIncome                                             None
# interestExpense                                       380000000
# nonInterestIncome                                    -481000000
# otherNonOperatingIncome                                 1000000
# depreciation                                         2200000000
# depreciationAndAmortization                           558000000
# incomeBeforeTax                                     22267000000
# incomeTaxExpense                                     5289000000
# interestAndDebtExpense                                380000000
# netIncomeFromContinuingOperations                   16978000000
# comprehensiveIncomeNetOfTax                         16537000000
# ebit                                                22647000000
# ebitda                                              23205000000
# netIncome                                           16978000000
#
# date                              1970-01-01 00:00:00.000000012  \
# fiscalDateEnding                                     2011-06-30
# reportedCurrency                                            USD
# grossProfit                                         54366000000
# totalRevenue                                        69943000000
# costOfRevenue                                       15577000000
# costofGoodsAndServicesSold                          15577000000
# operatingIncome                                     27161000000
# sellingGeneralAndAdministrative                     18162000000
# researchAndDevelopment                               9043000000
# operatingExpenses                                   27205000000
# investmentIncomeNet                                   900000000
# netInterestIncome                                    -295000000
# interestIncome                                             None
# interestExpense                                       295000000
# nonInterestIncome                                    -103000000
# otherNonOperatingIncome                               -31000000
# depreciation                                         2000000000
# depreciationAndAmortization                           537000000
# incomeBeforeTax                                     28071000000
# incomeTaxExpense                                     4921000000
# interestAndDebtExpense                                295000000
# netIncomeFromContinuingOperations                   23150000000
# comprehensiveIncomeNetOfTax                         23958000000
# ebit                                                28366000000
# ebitda                                              28903000000
# netIncome                                           23150000000
#
# date                              1970-01-01 00:00:00.000000013
# fiscalDateEnding                                     2010-06-30
# reportedCurrency                                            USD
# grossProfit                                         50089000000
# totalRevenue                                        62484000000
# costOfRevenue                                       12395000000
# costofGoodsAndServicesSold                          12395000000
# operatingIncome                                     24098000000
# sellingGeneralAndAdministrative                     17218000000
# researchAndDevelopment                               8714000000
# operatingExpenses                                   26989000000
# investmentIncomeNet                                   843000000
# netInterestIncome                                    -151000000
# interestIncome                                             None
# interestExpense                                       151000000
# nonInterestIncome                                    -139000000
# otherNonOperatingIncome                                14000000
# depreciation                                         1800000000
# depreciationAndAmortization                           707000000
# incomeBeforeTax                                     25013000000
# incomeTaxExpense                                     6253000000
# interestAndDebtExpense                                151000000
# netIncomeFromContinuingOperations                   18760000000
# comprehensiveIncomeNetOfTax                         18846000000
# ebit                                                25164000000
# ebitda                                              25871000000
# netIncome                                           18760000000

# %%
from alpha_vantage.fundamentaldata import FundamentalData
key = '8FHEYWXTU6IPYSH4'
fd = FundamentalData(key, output_format= 'pandas' )
data= fd.get_cash_flow_quarterly('MSFT')
data[0].T
# Out:
# date                                               1970-01-01 00:00:00.000000000  \
# fiscalDateEnding                                                      2024-03-31
# reportedCurrency                                                             USD
# operatingCashflow                                                    31917000000
# paymentsForOperatingActivities                                        1026000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                          5476000000
# changeInOperatingAssets                                               2954000000
# depreciationDepletionAndAmortization                                  1853000000
# capitalExpenditures                                                  10952000000
# changeInReceivables                                                   2028000000
# changeInInventory                                                     -260000000
# profitLoss                                                           21939000000
# cashflowFromInvestment                                              -10700000000
# cashflowFromFinancing                                               -18808000000
# proceedsFromRepaymentsOfShortTermDebt                                -3810000000
# paymentsForRepurchaseOfCommonStock                                    4213000000
# paymentsForRepurchaseOfEquity                                         4213000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        5572000000
# dividendPayoutCommonStock                                             5572000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      522000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -3691000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                              None
# changeInExchangeRate                                                        None
# netIncome                                                            21939000000
#
# date                                               1970-01-01 00:00:00.000000001  \
# fiscalDateEnding                                                      2023-12-31
# reportedCurrency                                                             USD
# operatingCashflow                                                    18853000000
# paymentsForOperatingActivities                                         971000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                         -8121000000
# changeInOperatingAssets                                               2179000000
# depreciationDepletionAndAmortization                                  1708000000
# capitalExpenditures                                                   9735000000
# changeInReceivables                                                   2951000000
# changeInInventory                                                    -1474000000
# profitLoss                                                           21870000000
# cashflowFromInvestment                                              -71925000000
# cashflowFromFinancing                                               -10147000000
# proceedsFromRepaymentsOfShortTermDebt                                -8490000000
# paymentsForRepurchaseOfCommonStock                                    4000000000
# paymentsForRepurchaseOfEquity                                         4000000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        5574000000
# dividendPayoutCommonStock                                             5574000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      261000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -3739000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                              None
# changeInExchangeRate                                                        None
# netIncome                                                            21870000000
#
# date                                               1970-01-01 00:00:00.000000002  \
# fiscalDateEnding                                                      2023-09-30
# reportedCurrency                                                             USD
# operatingCashflow                                                    30583000000
# paymentsForOperatingActivities                                         944000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                         -5302000000
# changeInOperatingAssets                                              -7720000000
# depreciationDepletionAndAmortization                                  1016000000
# capitalExpenditures                                                   9917000000
# changeInReceivables                                                 -11034000000
# changeInInventory                                                      505000000
# profitLoss                                                           22291000000
# cashflowFromInvestment                                                 503000000
# cashflowFromFinancing                                                14761000000
# proceedsFromRepaymentsOfShortTermDebt                                18692000000
# paymentsForRepurchaseOfCommonStock                                    4831000000
# paymentsForRepurchaseOfEquity                                         4831000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        5051000000
# dividendPayoutCommonStock                                             5051000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      685000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -4146000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                              None
# changeInExchangeRate                                                        None
# netIncome                                                            22291000000
#
# date                                               1970-01-01 00:00:00.000000003  \
# fiscalDateEnding                                                      2023-06-30
# reportedCurrency                                                             USD
# operatingCashflow                                                    28770000000
# paymentsForOperatingActivities                                         854000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                         19080000000
# changeInOperatingAssets                                              14837000000
# depreciationDepletionAndAmortization                                 11958000000
# capitalExpenditures                                                   8943000000
# changeInReceivables                                                  11244000000
# changeInInventory                                                     -374000000
# profitLoss                                                           20081000000
# cashflowFromInvestment                                               -9134000000
# cashflowFromFinancing                                               -11413000000
# proceedsFromRepaymentsOfShortTermDebt                                          0
# paymentsForRepurchaseOfCommonStock                                    5704000000
# paymentsForRepurchaseOfEquity                                         5704000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        5054000000
# dividendPayoutCommonStock                                             5054000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      512000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -5192000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                              None
# changeInExchangeRate                                                        None
# netIncome                                                            20081000000
#
# date                                               1970-01-01 00:00:00.000000004  \
# fiscalDateEnding                                                      2023-03-31
# reportedCurrency                                                             USD
# operatingCashflow                                                    24441000000
# paymentsForOperatingActivities                                         822000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                          2547000000
# changeInOperatingAssets                                                704000000
# depreciationDepletionAndAmortization                                   960000000
# capitalExpenditures                                                   6607000000
# changeInReceivables                                                   1408000000
# changeInInventory                                                     -106000000
# profitLoss                                                           18299000000
# cashflowFromInvestment                                               -3264000000
# cashflowFromFinancing                                               -10290000000
# proceedsFromRepaymentsOfShortTermDebt                                          0
# paymentsForRepurchaseOfCommonStock                                    5509000000
# paymentsForRepurchaseOfEquity                                         5509000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        5059000000
# dividendPayoutCommonStock                                             5059000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      536000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -4973000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                       10887000000
# changeInExchangeRate                                                        None
# netIncome                                                            18299000000
#
# date                                               1970-01-01 00:00:00.000000005  \
# fiscalDateEnding                                                      2022-12-31
# reportedCurrency                                                             USD
# operatingCashflow                                                    11173000000
# paymentsForOperatingActivities                                         764000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                         -8031000000
# changeInOperatingAssets                                               2316000000
# depreciationDepletionAndAmortization                                  1089000000
# capitalExpenditures                                                   6274000000
# changeInReceivables                                                   3164000000
# changeInInventory                                                    -1305000000
# profitLoss                                                           16425000000
# cashflowFromInvestment                                               -7150000000
# cashflowFromFinancing                                               -11349000000
# proceedsFromRepaymentsOfShortTermDebt                                          0
# paymentsForRepurchaseOfCommonStock                                    5459000000
# paymentsForRepurchaseOfEquity                                         5459000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        5066000000
# dividendPayoutCommonStock                                             5066000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      243000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -5216000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                       -7326000000
# changeInExchangeRate                                                        None
# netIncome                                                            16425000000
#
# date                                               1970-01-01 00:00:00.000000006  \
# fiscalDateEnding                                                      2022-09-30
# reportedCurrency                                                             USD
# operatingCashflow                                                    23198000000
# paymentsForOperatingActivities                                         767000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                         -8315000000
# changeInOperatingAssets                                             -10188000000
# depreciationDepletionAndAmortization                                   822000000
# capitalExpenditures                                                   6283000000
# changeInReceivables                                                 -11729000000
# changeInInventory                                                      543000000
# profitLoss                                                           17556000000
# cashflowFromInvestment                                               -3132000000
# cashflowFromFinancing                                               -10883000000
# proceedsFromRepaymentsOfShortTermDebt                                          0
# paymentsForRepurchaseOfCommonStock                                    5573000000
# paymentsForRepurchaseOfEquity                                         5573000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        4621000000
# dividendPayoutCommonStock                                             4621000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      575000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -4998000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                        9183000000
# changeInExchangeRate                                                        None
# netIncome                                                            17556000000
#
# date                                               1970-01-01 00:00:00.000000007  \
# fiscalDateEnding                                                      2022-06-30
# reportedCurrency                                                             USD
# operatingCashflow                                                    24629000000
# paymentsForOperatingActivities                                         744000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                         17713000000
# changeInOperatingAssets                                              16240000000
# depreciationDepletionAndAmortization                                 13401000000
# capitalExpenditures                                                   6871000000
# changeInReceivables                                                  12634000000
# changeInInventory                                                      461000000
# profitLoss                                                           16740000000
# cashflowFromInvestment                                               -9729000000
# cashflowFromFinancing                                               -13269000000
# proceedsFromRepaymentsOfShortTermDebt                                          0
# paymentsForRepurchaseOfCommonStock                                    8757000000
# paymentsForRepurchaseOfEquity                                         8757000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        4632000000
# dividendPayoutCommonStock                                             4632000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      461000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -8296000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                        1574000000
# changeInExchangeRate                                                        None
# netIncome                                                            16740000000
#
# date                                               1970-01-01 00:00:00.000000008  \
# fiscalDateEnding                                                      2022-03-31
# reportedCurrency                                                             USD
# operatingCashflow                                                    25386000000
# paymentsForOperatingActivities                                         835000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                          3127000000
# changeInOperatingAssets                                                 55000000
# depreciationDepletionAndAmortization                                   791000000
# capitalExpenditures                                                   5340000000
# changeInReceivables                                                   -857000000
# changeInInventory                                                      279000000
# profitLoss                                                           16728000000
# cashflowFromInvestment                                              -16171000000
# cashflowFromFinancing                                               -17345000000
# proceedsFromRepaymentsOfShortTermDebt                                          0
# paymentsForRepurchaseOfCommonStock                                    8822000000
# paymentsForRepurchaseOfEquity                                         8822000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        4645000000
# dividendPayoutCommonStock                                             4645000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      477000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -8345000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                       -8106000000
# changeInExchangeRate                                                    24000000
# netIncome                                                            16728000000
#
# date                                               1970-01-01 00:00:00.000000009  \
# fiscalDateEnding                                                      2021-12-31
# reportedCurrency                                                             USD
# operatingCashflow                                                    14480000000
# paymentsForOperatingActivities                                         548000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                         -4327000000
# changeInOperatingAssets                                               5227000000
# depreciationDepletionAndAmortization                                   710000000
# capitalExpenditures                                                   5865000000
# changeInReceivables                                                   5543000000
# changeInInventory                                                     -394000000
# profitLoss                                                           18765000000
# cashflowFromInvestment                                               -1161000000
# cashflowFromFinancing                                               -11986000000
# proceedsFromRepaymentsOfShortTermDebt                                          0
# paymentsForRepurchaseOfCommonStock                                    7433000000
# paymentsForRepurchaseOfEquity                                         7433000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        4652000000
# dividendPayoutCommonStock                                             4652000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      291000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -7142000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                        1439000000
# changeInExchangeRate                                                   106000000
# netIncome                                                            18765000000
#
# date                                                ...  \
# fiscalDateEnding                                    ...
# reportedCurrency                                    ...
# operatingCashflow                                   ...
# paymentsForOperatingActivities                      ...
# proceedsFromOperatingActivities                     ...
# changeInOperatingLiabilities                        ...
# changeInOperatingAssets                             ...
# depreciationDepletionAndAmortization                ...
# capitalExpenditures                                 ...
# changeInReceivables                                 ...
# changeInInventory                                   ...
# profitLoss                                          ...
# cashflowFromInvestment                              ...
# cashflowFromFinancing                               ...
# proceedsFromRepaymentsOfShortTermDebt               ...
# paymentsForRepurchaseOfCommonStock                  ...
# paymentsForRepurchaseOfEquity                       ...
# paymentsForRepurchaseOfPreferredStock               ...
# dividendPayout                                      ...
# dividendPayoutCommonStock                           ...
# dividendPayoutPreferredStock                        ...
# proceedsFromIssuanceOfCommonStock                   ...
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...  ...
# proceedsFromIssuanceOfPreferredStock                ...
# proceedsFromRepurchaseOfEquity                      ...
# proceedsFromSaleOfTreasuryStock                     ...
# changeInCashAndCashEquivalents                      ...
# changeInExchangeRate                                ...
# netIncome                                           ...
#
# date                                               1970-01-01 00:00:00.000000049  \
# fiscalDateEnding                                                      2011-12-31
# reportedCurrency                                                             USD
# operatingCashflow                                                     5862000000
# paymentsForOperatingActivities                                           4000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                          7978000000
# changeInOperatingAssets                                               2126000000
# depreciationDepletionAndAmortization                                   155000000
# capitalExpenditures                                                    498000000
# changeInReceivables                                                   3652000000
# changeInInventory                                                     -891000000
# profitLoss                                                            6624000000
# cashflowFromInvestment                                               -5568000000
# cashflowFromFinancing                                                -2513000000
# proceedsFromRepaymentsOfShortTermDebt                                          0
# paymentsForRepurchaseOfCommonStock                                    1042000000
# paymentsForRepurchaseOfEquity                                         1042000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        1683000000
# dividendPayoutCommonStock                                             1683000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      208000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                        -834000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                       -2271000000
# changeInExchangeRate                                                   -52000000
# netIncome                                                             6624000000
#
# date                                               1970-01-01 00:00:00.000000050  \
# fiscalDateEnding                                                      2011-09-30
# reportedCurrency                                                             USD
# operatingCashflow                                                     8493000000
# paymentsForOperatingActivities                                          70000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                          4758000000
# changeInOperatingAssets                                              -3998000000
# depreciationDepletionAndAmortization                                   109000000
# capitalExpenditures                                                    436000000
# changeInReceivables                                                  -4733000000
# changeInInventory                                                      920000000
# profitLoss                                                            5738000000
# cashflowFromInvestment                                               -2315000000
# cashflowFromFinancing                                                -2869000000
# proceedsFromRepaymentsOfShortTermDebt                                          0
# paymentsForRepurchaseOfCommonStock                                    1934000000
# paymentsForRepurchaseOfEquity                                         1934000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        1341000000
# dividendPayoutCommonStock                                             1341000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      336000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -1598000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                        3271000000
# changeInExchangeRate                                                   -38000000
# netIncome                                                             5738000000
#
# date                                               1970-01-01 00:00:00.000000051  \
# fiscalDateEnding                                                      2011-06-30
# reportedCurrency                                                             USD
# operatingCashflow                                                     5942000000
# paymentsForOperatingActivities                                         183000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                         12277000000
# changeInOperatingAssets                                               6071000000
# depreciationDepletionAndAmortization                                  1588000000
# capitalExpenditures                                                    642000000
# changeInReceivables                                                   4886000000
# changeInInventory                                                      303000000
# profitLoss                                                           13659000000
# cashflowFromInvestment                                                -950000000
# cashflowFromFinancing                                                -2423000000
# proceedsFromRepaymentsOfShortTermDebt                                          0
# paymentsForRepurchaseOfCommonStock                                    1256000000
# paymentsForRepurchaseOfEquity                                         1256000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        1350000000
# dividendPayoutCommonStock                                             1350000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      180000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -1076000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                        2589000000
# changeInExchangeRate                                                    20000000
# netIncome                                                             5874000000
#
# date                                               1970-01-01 00:00:00.000000052  \
# fiscalDateEnding                                                      2011-03-31
# reportedCurrency                                                             USD
# operatingCashflow                                                     8672000000
# paymentsForOperatingActivities                                           5000000
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                          7045000000
# changeInOperatingAssets                                              -2235000000
# depreciationDepletionAndAmortization                                   162000000
# capitalExpenditures                                                    658000000
# changeInReceivables                                                  -3031000000
# changeInInventory                                                      170000000
# profitLoss                                                            5232000000
# cashflowFromInvestment                                               -7139000000
# cashflowFromFinancing                                                 1437000000
# proceedsFromRepaymentsOfShortTermDebt                                          0
# paymentsForRepurchaseOfCommonStock                                     848000000
# paymentsForRepurchaseOfEquity                                          848000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        1349000000
# dividendPayoutCommonStock                                             1349000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                     1405000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                         557000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                        2998000000
# changeInExchangeRate                                                    28000000
# netIncome                                                             5232000000
#
# date                                               1970-01-01 00:00:00.000000053  \
# fiscalDateEnding                                                      2010-12-31
# reportedCurrency                                                             USD
# operatingCashflow                                                     4186000000
# paymentsForOperatingActivities                                              None
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                           663000000
# changeInOperatingAssets                                               2890000000
# depreciationDepletionAndAmortization                                   126000000
# capitalExpenditures                                                    491000000
# changeInReceivables                                                   3270000000
# changeInInventory                                                     -380000000
# profitLoss                                                            6634000000
# cashflowFromInvestment                                               -1570000000
# cashflowFromFinancing                                                -6751000000
# proceedsFromRepaymentsOfShortTermDebt                                -2000000000
# paymentsForRepurchaseOfCommonStock                                    5052000000
# paymentsForRepurchaseOfEquity                                         5052000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        1363000000
# dividendPayoutCommonStock                                             1363000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      660000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -4392000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                       -4138000000
# changeInExchangeRate                                                    -3000000
# netIncome                                                             6634000000
#
# date                                               1970-01-01 00:00:00.000000054  \
# fiscalDateEnding                                                      2010-09-30
# reportedCurrency                                                             USD
# operatingCashflow                                                     8194000000
# paymentsForOperatingActivities                                              None
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                           327000000
# changeInOperatingAssets                                              -3206000000
# depreciationDepletionAndAmortization                                   124000000
# capitalExpenditures                                                    564000000
# changeInReceivables                                                  -3674000000
# changeInInventory                                                      468000000
# profitLoss                                                            5410000000
# cashflowFromInvestment                                               -4957000000
# cashflowFromFinancing                                                 -639000000
# proceedsFromRepaymentsOfShortTermDebt                                  814000000
# paymentsForRepurchaseOfCommonStock                                    4399000000
# paymentsForRepurchaseOfEquity                                         4399000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        1118000000
# dividendPayoutCommonStock                                             1118000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      177000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -4222000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                        2656000000
# changeInExchangeRate                                                    58000000
# netIncome                                                             5410000000
#
# date                                               1970-01-01 00:00:00.000000055  \
# fiscalDateEnding                                                      2010-06-30
# reportedCurrency                                                             USD
# operatingCashflow                                                     5604000000
# paymentsForOperatingActivities                                              None
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                         -2612000000
# changeInOperatingAssets                                               4144000000
# depreciationDepletionAndAmortization                                   718000000
# capitalExpenditures                                                    758000000
# changeInReceivables                                                   4144000000
# changeInInventory                                                      260000000
# profitLoss                                                           12869000000
# cashflowFromInvestment                                               -4119000000
# cashflowFromFinancing                                                -4098000000
# proceedsFromRepaymentsOfShortTermDebt                                 -545000000
# paymentsForRepurchaseOfCommonStock                                    3839000000
# paymentsForRepurchaseOfEquity                                         3839000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        1127000000
# dividendPayoutCommonStock                                             1127000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      912000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -1127000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                       -2650000000
# changeInExchangeRate                                                   -37000000
# netIncome                                                             4518000000
#
# date                                               1970-01-01 00:00:00.000000056  \
# fiscalDateEnding                                                      2010-03-31
# reportedCurrency                                                             USD
# operatingCashflow                                                     7393000000
# paymentsForOperatingActivities                                              None
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                          -117000000
# changeInOperatingAssets                                              -1947000000
# depreciationDepletionAndAmortization                                   694000000
# capitalExpenditures                                                    408000000
# changeInReceivables                                                  -1947000000
# changeInInventory                                                      -77000000
# profitLoss                                                            4006000000
# cashflowFromInvestment                                               -5904000000
# cashflowFromFinancing                                                -2726000000
# proceedsFromRepaymentsOfShortTermDebt                                 -349000000
# paymentsForRepurchaseOfCommonStock                                    2023000000
# paymentsForRepurchaseOfEquity                                         2023000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        1139000000
# dividendPayoutCommonStock                                             1139000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      422000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -1601000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                       -1267000000
# changeInExchangeRate                                                   -30000000
# netIncome                                                             4006000000
#
# date                                               1970-01-01 00:00:00.000000057  \
# fiscalDateEnding                                                      2009-12-31
# reportedCurrency                                                             USD
# operatingCashflow                                                     4969000000
# paymentsForOperatingActivities                                              None
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                          -623000000
# changeInOperatingAssets                                               2789000000
# depreciationDepletionAndAmortization                                   615000000
# capitalExpenditures                                                    376000000
# changeInReceivables                                                   2789000000
# changeInInventory                                                     -558000000
# profitLoss                                                            6662000000
# cashflowFromInvestment                                                 -92000000
# cashflowFromFinancing                                                -4277000000
# proceedsFromRepaymentsOfShortTermDebt                                 -475000000
# paymentsForRepurchaseOfCommonStock                                    3867000000
# paymentsForRepurchaseOfEquity                                         3867000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        1152000000
# dividendPayoutCommonStock                                             1152000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      729000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -3138000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                         599000000
# changeInExchangeRate                                                    -1000000
# netIncome                                                             6662000000
#
# date                                               1970-01-01 00:00:00.000000058
# fiscalDateEnding                                                      2009-09-30
# reportedCurrency                                                             USD
# operatingCashflow                                                     6107000000
# paymentsForOperatingActivities                                              None
# proceedsFromOperatingActivities                                             None
# changeInOperatingLiabilities                                          1850000000
# changeInOperatingAssets                                              -2748000000
# depreciationDepletionAndAmortization                                   646000000
# capitalExpenditures                                                    435000000
# changeInReceivables                                                  -2748000000
# changeInInventory                                                      419000000
# profitLoss                                                            3574000000
# cashflowFromInvestment                                               -1199000000
# cashflowFromFinancing                                                -2190000000
# proceedsFromRepaymentsOfShortTermDebt                                  378000000
# paymentsForRepurchaseOfCommonStock                                    1540000000
# paymentsForRepurchaseOfEquity                                         1540000000
# paymentsForRepurchaseOfPreferredStock                                       None
# dividendPayout                                                        1157000000
# dividendPayoutCommonStock                                             1157000000
# dividendPayoutPreferredStock                                                None
# proceedsFromIssuanceOfCommonStock                                      248000000
# proceedsFromIssuanceOfLongTermDebtAndCapitalSec...                          None
# proceedsFromIssuanceOfPreferredStock                                        None
# proceedsFromRepurchaseOfEquity                                       -1292000000
# proceedsFromSaleOfTreasuryStock                                             None
# changeInCashAndCashEquivalents                                        2747000000
# changeInExchangeRate                                                    29000000
# netIncome                                                             3574000000
#
# [29 rows x 59 columns]

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies
cc= CryptoCurrencies(key,output_format='pandas')
data=cc.get_digital_currency_weekly('ETH', 'USD')
data[0].T
# Out:
# date          2024-06-14     2024-06-09     2024-06-02    2024-05-26  \
# 1. open      3706.400000    3778.880000    3823.550000  3.070830e+03
# 2. high      3712.600000    3888.900000    3973.900000  3.947000e+03
# 3. low       3381.000000    3575.230000    3700.400000  3.048580e+03
# 4. close     3471.750000    3706.270000    3778.880000  3.823830e+03
# 5. volume  390432.770681  404665.621725  539562.698239  1.200398e+06
#
# date          2024-05-19     2024-05-12     2024-05-05     2024-04-28  \
# 1. open      2927.720000    3136.770000    3262.990000    3148.060000
# 2. high      3148.000000    3221.410000    3287.150000    3356.310000
# 3. low       2858.760000    2878.380000    2814.120000    3067.270000
# 4. close     3070.900000    2927.750000    3136.950000    3262.600000
# 5. volume  501611.371454  380578.156653  589410.147409  526283.911427
#
# date         2024-04-21    2024-04-14  ...     2023-10-29     2023-10-22  \
# 1. open      3158.20000    3453.69000  ...    1664.430000    1558.010000
# 2. high      3281.21000    3729.16000  ...    1865.860000    1668.280000
# 3. low       2865.71000    2850.00000  ...    1657.950000    1542.360000
# 4. close     3148.07000    3158.34000  ...    1795.740000    1664.430000
# 5. volume  663812.48603  940169.52313  ...  914408.592287  559729.866724
#
# date          2023-10-15     2023-10-08     2023-10-01     2023-09-24  \
# 1. open      1633.770000    1733.420000    1580.590000    1622.930000
# 2. high      1636.510000    1743.840000    1755.200000    1669.430000
# 3. low       1520.850000    1608.000000    1563.000000    1567.810000
# 4. close     1558.010000    1633.780000    1733.400000    1580.640000
# 5. volume  442640.509216  538473.660851  553557.334879  375543.523842
#
# date          2023-09-17     2023-09-10     2023-09-03     2023-08-27
# 1. open      1616.680000    1635.650000    1657.500000    1685.360000
# 2. high      1653.520000    1669.000000    1745.880000    1700.460000
# 3. low       1530.600000    1596.780000    1601.690000    1579.340000
# 4. close     1622.830000    1616.650000    1635.670000    1657.510000
# 5. volume  471170.444467  341058.861244  520049.503201  503401.959121
#
# [5 rows x 43 columns]
